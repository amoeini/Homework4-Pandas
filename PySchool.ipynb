# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# File to Load (Remember to Change These)
school_data_to_load = "Resources/schools_complete.csv"
student_data_to_load = "Resources/students_complete.csv"

# Read School and Student Data File and store into Pandas Data Frames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)
pd.DataFrame(school_data).head()
pd.DataFrame(student_data).head()

# Combine the data into a single dataset
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])
school_data_complete
# Out:
#        Student ID         student_name gender grade         school_name  \
# 0               0         Paul Bradley      M   9th   Huang High School
# 1               1         Victor Smith      M  12th   Huang High School
# 2               2      Kevin Rodriguez      M  12th   Huang High School
# 3               3    Dr. Richard Scott      M  12th   Huang High School
# 4               4           Bonnie Ray      F   9th   Huang High School
# 5               5        Bryan Miranda      M   9th   Huang High School
# 6               6        Sheena Carter      F  11th   Huang High School
# 7               7         Nicole Baker      F  12th   Huang High School
# 8               8         Michael Roth      M  10th   Huang High School
# 9               9       Matthew Greene      M  10th   Huang High School
# 10             10     Andrew Alexander      M  10th   Huang High School
# 11             11        Daniel Cooper      M  10th   Huang High School
# ...

# %% [markdown]
# ### District Summary
# Calculate the total number of schools
#
# Calculate the total number of students
#
# Calculate the total budget
#
# Calculate the average math score
#
# Calculate the average reading score
#
# Calculate the overall passing rate (overall average score), i.e. (avg. math score + avg. reading score)/2
#
# Calculate the percentage of students with a passing math score (70 or greater)
#
# Calculate the percentage of students with a passing reading score (70 or greater)
#
# Create a dataframe to hold the above results
#
# Optional: give the displayed data cleaner formatting

# %%
# total number of schools
unique_schools = school_data_complete['school_name'].unique()
number_of_schools = unique_schools.size
print(number_of_schools)
print(unique_schools)

# total budget
unique_df = school_data_complete.drop_duplicates('school_name')
print(unique_df)
print(unique_df['school_name'].unique())
#unique = school_data_complete.loc[school_data_complete['school_name'] == school_data_complete['school_name'].unique()]
total_budget = school_data_complete


# total number of students
number_of_students = school_data_complete.shape[0]
print(number_of_students)

# average math/reading scores
math_avg = school_data_complete['math_score'].mean()
reading_avg = school_data_complete['reading_score'].mean()

# overall average rate
overall_passing_rate = (math_avg + reading_avg)/2

total_budget
# Out:
# 15
# ['Huang High School' 'Figueroa High School' 'Shelton High School'
#  'Hernandez High School' 'Griffin High School' 'Wilson High School'
#  'Cabrera High School' 'Bailey High School' 'Holden High School'
#  'Pena High School' 'Wright High School' 'Rodriguez High School'
#  'Johnson High School' 'Ford High School' 'Thomas High School']
#        Student ID      student_name gender grade            school_name  \
# 0               0      Paul Bradley      M   9th      Huang High School
# 2917         2917        Amy Jacobs      F  10th   Figueroa High School
# 5866         5866  Jamie Montgomery      F  12th    Shelton High School
# 7627         7627     Russell Davis      M  10th  Hernandez High School
# 12262       12262    Heather Wright      F  11th    Griffin High School
# 13730       13730    Kelli Anderson      F  10th     Wilson High School
# 16013       16013      Olivia Short      F  11th    Cabrera High School
# ...

# %%
my_shape = school_data_complete.shape
my_shape
# Out:
# (39170, 11)

# %%
for i in range(my_shape[0]):
    for j in range(my_shape[1]):
        print(school_data_complete.iloc[i,j])
# Out:
# 0
# Paul Bradley
# M
# 9th
# Huang High School
# 66
# 79
# 0
# District
# 2917
# 1910635
# 1
# Victor Smith
# M
# 12th
# Huang High School
# 94
# 61
# 0
# District
# 2917
# 1910635
# 2
# Kevin Rodriguez
# M
# 12th
# Huang High School
# 90
# 60
# 0
# District
# 2917
# 1910635
# 3
# Dr. Richard Scott
# M
# 12th
# Huang High School
# 67
# 58
# 0
# District
# 2917
# 1910635
# 4
# Bonnie Ray
# F
# 9th
# Huang High School
# 97
# 84
# 0
# District
# 2917
# 1910635
# 5
# Bryan Miranda
# M
# 9th
# Huang High School
# 94
# 94
# 0
# District
# 2917
# 1910635
# 6
# Sheena Carter
# F
# 11th
# Huang High School
# 82
# 80
# 0
# District
# 2917
# 1910635
# 7
# Nicole Baker
# F
# 12th
# Huang High School
# 96
# 69
# 0
# District
# 2917
# 1910635
# 8
# Michael Roth
# M
# 10th
# Huang High School
# 95
# 87
# 0
# District
# 2917
# 1910635
# 9
# Matthew Greene
# M
# 10th
# Huang High School
# 96
# 84
# 0
# District
# 2917
# 1910635
# 10
# Andrew Alexander
# M
# 10th
# Huang High School
# 90
# 70
# 0
# ...
